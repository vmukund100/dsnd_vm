# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
dfb_calendar = pd.read_csv('./bcalendar.csv')
dfb_listings = pd.read_csv('./blistings.csv')
dfb_reviews = pd.read_csv('./breviews.csv')

# %%
# A firt check - data types, enteries, columns, missing data
dfb_calendar.info()
dfb_calendar.shape[0]
dfb_calendar.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1308890 entries, 0 to 1308889
# Data columns (total 4 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   listing_id  1308890 non-null  int64
#  1   date        1308890 non-null  object
#  2   available   1308890 non-null  object
#  3   price       643037 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 39.9+ MB
#          listing_id
# count  1.308890e+06
# mean   8.442118e+06
# std    4.500149e+06
# min    3.353000e+03
# 25%    4.679319e+06
# 50%    8.578710e+06
# 75%    1.279603e+07
# max    1.493346e+07

# %%
dfb_listings.info()
dfb_listings.shape[0]
dfb_listings.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3585 entries, 0 to 3584
# Data columns (total 95 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3585 non-null   int64
#  1   listing_url                       3585 non-null   object
#  2   scrape_id                         3585 non-null   int64
#  3   last_scraped                      3585 non-null   object
#  4   name                              3585 non-null   object
#  5   summary                           3442 non-null   object
#  6   space                             2528 non-null   object
#  7   description                       3585 non-null   object
#  8   experiences_offered               3585 non-null   object
#  9   neighborhood_overview             2170 non-null   object
#  10  notes                             1610 non-null   object
# ...

# %%
dfb_reviews.info()
dfb_reviews.shape[0]
dfb_reviews.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68275 entries, 0 to 68274
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   listing_id     68275 non-null  int64
#  1   id             68275 non-null  int64
#  2   date           68275 non-null  object
#  3   reviewer_id    68275 non-null  int64
#  4   reviewer_name  68275 non-null  object
#  5   comments       68222 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 3.1+ MB
#          listing_id            id   reviewer_id
# count  6.827500e+04  6.827500e+04  6.827500e+04
# mean   4.759910e+06  5.246516e+07  2.802389e+07
# std    3.788990e+06  2.790991e+07  2.234097e+07
# min    3.353000e+03  1.021000e+03  1.430000e+02
# 25%    1.458081e+06  3.010420e+07  9.001346e+06
# 50%    4.080000e+06  5.223121e+07  2.305179e+07
# 75%    7.377034e+06  7.663248e+07  4.213454e+07
# max    1.484378e+07  9.999045e+07  9.335034e+07

# %%
dfb_calendar.head()
# Out:
#    listing_id        date available price
# 0    12147973  2017-09-05         f   NaN
# 1    12147973  2017-09-04         f   NaN
# 2    12147973  2017-09-03         f   NaN
# 3    12147973  2017-09-02         f   NaN
# 4    12147973  2017-09-01         f   NaN

# %%
dfb_listings.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  12147973  https://www.airbnb.com/rooms/12147973  20160906204935
# 1   3075044   https://www.airbnb.com/rooms/3075044  20160906204935
# 2      6976      https://www.airbnb.com/rooms/6976  20160906204935
# 3   1436513   https://www.airbnb.com/rooms/1436513  20160906204935
# 4   7651065   https://www.airbnb.com/rooms/7651065  20160906204935
#
#   last_scraped                                           name  \
# 0   2016-09-07                     Sunny Bungalow in the City
# 1   2016-09-07              Charming room in pet friendly apt
# 2   2016-09-07               Mexican Folk Art Haven in Boston
# 3   2016-09-07  Spacious Sunny Bedroom Suite in Historic Home
# 4   2016-09-07                            Come Home to Boston
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# ...

# %%
dfb_reviews.head()
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0     1178162  4724140  2013-05-21      4298113       Olivier
# 1     1178162  4869189  2013-05-29      6452964     Charlotte
# 2     1178162  5003196  2013-06-06      6449554     Sebastian
# 3     1178162  5150351  2013-06-15      2215611        Marine
# 4     1178162  5171140  2013-06-16      6848427        Andrew
#
#                                             comments
# 0  My stay at islam's place was really cool! Good...
# 1  Great location for both airport and city - gre...
# 2  We really enjoyed our stay at Islams house. Fr...
# 3  The room was nice and clean and so were the co...
# 4  Great location. Just 5 mins walk from the Airp...

# %%
dfb_listings_corr = dfb_listings.drop(['square_feet', 'license'], axis=1)

# %%
obj_dfb2_corr = dfb_listings_corr.select_dtypes(include = ['object']).copy()
obj_dfb2_corr.shape
# Out:
# (3585, 62)

# %%
obj_dfb2_corr.columns
# Out:
# Index(['listing_url', 'last_scraped', 'name', 'summary', 'space',
#        'description', 'experiences_offered', 'neighborhood_overview', 'notes',
#        'transit', 'access', 'interaction', 'house_rules', 'thumbnail_url',
#        'medium_url', 'picture_url', 'xl_picture_url', 'host_url', 'host_name',
#        'host_since', 'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed', 'city', 'state',
#        'zipcode', 'market', 'smart_location', 'country_code', 'country',
#        'is_location_exact', 'property_type', 'room_type', 'bed_type',
#        'amenities', 'price', 'weekly_price', 'monthly_price',
#        'security_deposit', 'cleaning_fee', 'extra_people', 'calendar_updated',
# ...

# %%
no_nullsdfb2 = set(obj_dfb2_corr.columns[obj_dfb2_corr.isnull().mean()==0]) #set of colums with no missing values in df2_corr
len(no_nullsdfb2)
# Out:
# 34

# %%
np.sum(np.sum(obj_dfb2_corr.isnull())/obj_dfb2_corr.shape[0] < 0.5)
# Out:
# 58

# %%
prop_type = dfb_listings.property_type.value_counts()
plt.figure(figsize=(12,5));
(prop_type/dfb_listings.shape[0]).plot(kind='bar');
plt.xticks(rotation=60);
plt.title('Availability of different property types in Boston city ');
plt.xlabel('Property Type');
plt.ylabel('% Availability');

# %%
#Exploring neighbourhood and neighbourhood distribution
neighbourhood = dfb_listings.neighbourhood.value_counts()[:40]
plt.figure(figsize=(14,8))
(neighbourhood/dfb_listings.shape[0]).plot(kind="bar");
plt.title("Availability across different neighbourhoods in Boston");
plt.xlabel('Neighbourhoods');

# %%
import datetime
import folium #Longitude and Lattitude mapping.from sklearn.linear_model import LinearRegression #We don't this in the analysis I am currently showing.
import folium
from folium import plugins
from folium.plugins import MarkerCluster #To be able to cluster our individual data points on folium.
from IPython.display import HTML, display

# %%
#dropping rows with Nan values anywhere in the calendar and review data
dfb_calendar = dfb_calendar.dropna(axis = 0, subset = ['price'], how = 'any')
dfb_reviews = dfb_reviews.dropna(axis = 0, subset = ['comments'], how = 'any')
#Stripping date column(object type) to month, year and day
dfb_calendar['date'] = pd.to_datetime(dfb_calendar['date'])
dfb_calendar['month'] = dfb_calendar.date.dt.month
dfb_calendar['year'] = dfb_calendar.date.dt.year
dfb_calendar['day'] = dfb_calendar.date.dt.day
#dfb_calendar['price'] = pd.to_numeric(dfb_calendar['price'].apply(lambda x: str(x).replace('$', '').replace(',', '')), 
#                                      errors='coerce')

# %%
# Function to convert price columns masquerading as object type columns & removing the $, symbols
def str_to_num(df,column):
    """Description: This function is for the price columns. They are object types.
    Covert datatype to string and removes the $ and quotes. 
    
    Arguments: 
    column: price
    df: dataframe
    
    Returns: 
    return the price columns back as float"""
    df[column] = pd.to_numeric(df[column].apply(lambda x : str(x).replace('$','').replace(",",'')),errors='coerce')
    return df

columns = ['price','monthly_price','weekly_price','security_deposit','cleaning_fee', 'extra_people']

for col in columns:
    dfb_listings = str_to_num(dfb_listings,col)

# %%
piece_listingb = dfb_listings[['property_type', 'neighbourhood', 'review_scores_value', 
                        'bathrooms', 'bedrooms', 'price', 'longitude', 'latitude']]
print(len(piece_listingb))
new_listingb = piece_listingb.dropna(axis = 0, how = 'any')
print(len(new_listingb))
new_listingb.info()
# Out:
# 3585
# 2341
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2341 entries, 1 to 3583
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_type        2341 non-null   object
#  1   neighbourhood        2341 non-null   object
#  2   review_scores_value  2341 non-null   float64
#  3   bathrooms            2341 non-null   float64
#  4   bedrooms             2341 non-null   float64
#  5   price                2341 non-null   float64
#  6   longitude            2341 non-null   float64
#  7   latitude             2341 non-null   float64
# dtypes: float64(6), object(2)
# memory usage: 164.6+ KB

# %%
(len(new_listingb)-new_listingb.count())/len(new_listingb)*100
# Out:
# property_type          0.0
# neighbourhood          0.0
# review_scores_value    0.0
# bathrooms              0.0
# bedrooms               0.0
# price                  0.0
# longitude              0.0
# latitude               0.0
# dtype: float64

# %%
def Filter2_by_property_type(category, filepath):
    """Description: This function can be used to read the dataframe and seive out data by one property_type.
    
    Arguments: 
    category: category of the property_type
    filepath: datframe
    
    Returns: 
    A data frame including just that property_type"""
    
    property_type = [category]
    true_false_by_property = new_listingb.property_type.isin(property_type) 
    table1 = new_listingb[true_false_by_property]
    return table1

# %%
Apartment_listb1 = Filter2_by_property_type('Apartment', new_listingb)
Apartment_listb1
# Out:
#      property_type neighbourhood  review_scores_value  bathrooms  bedrooms  \
# 1        Apartment    Roslindale                  9.0        1.0       1.0
# 2        Apartment    Roslindale                 10.0        1.0       1.0
# 9        Apartment    Roslindale                  9.0        1.0       2.0
# 13       Apartment    Roslindale                 10.0        1.0       2.0
# 15       Apartment    Roslindale                 10.0        0.0       1.0
# ...            ...           ...                  ...        ...       ...
# 3571     Apartment     Brookline                 10.0        1.0       1.0
# 3573     Apartment    Somerville                 10.0        1.0       1.0
# 3575     Apartment    Somerville                  7.0        1.0       1.0
# 3580     Apartment    Somerville                  9.0        1.0       1.0
# 3583     Apartment    Somerville                  7.0        1.0       1.0
#
#       price  longitude   latitude
# ...

# %%
def map_plot(x, y, data_list):
    """The latitude and longitude columns in data is already given. So plot the seattle map 
    Then we use group the data according to a list. 
    The desired list is derived from the property_type (generated b Filter_by_property_type)
    
    Arguements: 
        latitude: columns containing latitude coordinates.
        longitude: columns containing longitude coordinates.
        data_list: Data list where columns are held.
    
    Returns:
    Clustered map of all data points."""
    
    #Creates a map of Boston
    m = folium.Map(location=[42.28, -71.13], zoom_start = 12)
    m.save('index.html')


    #Takes the latitude and longitude coordinates and zips them into a form to be plotted.
    lat = pd.to_numeric(data_list[x], errors = 'coerce')
    lon = pd.to_numeric(data_list[y], errors = 'coerce')

    #Zip togethers each list of latitude and longitude coordinates. 
    result = zip(lat,lon)
    lat_lon = list(result)


    mc = MarkerCluster().add_to(m)
    for i in range(0,len(data_list)):
        folium.Marker(location=lat_lon[i]).add_to(mc)

    m.save('index.html')
    display(m)

# %%
map_plot('latitude', 'longitude', Apartment_listb1)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
plt.figure(figsize=(14,6));
dfb_listings.groupby(['property_type'])['price'].mean().sort_values(ascending=False).plot(kind='bar');
plt.title('Property price as per Property Type');
plt.xlabel('Property Type');
plt.ylabel('$ Price');

# %%
# Common column/feature - listing_id; dfs2 has the same column named as 'id'. Chnage this to listing_id

# %%
(dfb_listings.groupby('neighbourhood')['price'].mean().sort_values(ascending=False)).plot(kind="bar", figsize=(16,8));
plt.title("Average Listing price across Boston neighbourhoods");
plt.xlabel('Neighbourhood');
plt.ylabel('Average Price');

# %%
# to clean the price and convert it into a float 
dfb_calendar['date'] = pd.to_datetime(dfb_calendar.date)
dfb_calendar = dfb_calendar.dropna(subset=['price'], axis = 0)
dfb_calendar = str_to_num(dfb_calendar,'price')
# add month and year column to the calender dataset
dfb_calendar['month'], dfb_calendar['year'] = dfb_calendar.date.dt.month, dfb_calendar.date.dt.year

# %%
# Average booking price across the different months of the year
average_price_by_month = dfb_calendar.groupby(['month'])['price'].mean()
plt.figure(figsize=(10,5))
plt.plot(average_price_by_month)
plt.ylabel('Average price, $')
plt.xlabel('Month')
plt.title('Average price')

plt.savefig('averagePrice_year')

plt.show()

# %%
numcols_dfb2_corr = dfb_listings_corr.select_dtypes(include = ['float', 'int']).copy()
numcols_dfb2_corr.shape
# Out:
# (3585, 16)

# %%
# without any changes, a set of plots with the existing numerical columns 
numcols_dfb2_corr.hist(figsize=(16, 20), bins=20, xlabelsize=8, ylabelsize=8);

# %%
available_count_daily = dfb_calendar.groupby('date').count()[['price']]
available_count_daily = available_count_daily.rename({"price":"available_listings"},axis='columns')

average_price_daily = dfb_calendar.groupby('date').mean()[['price']]
# change column name
average_price_daily = average_price_daily.rename({"price":"average_prices"},axis='columns')

# %%
# plot total available houses and average prices in one figure
f, ax = plt.subplots(figsize=(15, 6))
plt1 = sns.lineplot(x = available_count_daily.index,y = 'available_listings', 
                  data = available_count_daily,color="g",legend=False,label='Number of listings available')

ax2 = ax.twinx()
plt2 = sns.lineplot(x = average_price_daily.index,y = 'average_prices',
             data=average_price_daily,ax=ax2,linestyle=':', legend=False,label='Daily prices')
ax.set_title('Comparing the daily availability of airbnb listing with the daily listing prices in Boston');
ax2.legend();
ax.legend();
plt.savefig('CompareAvailabilityPriceWithDates_Boston.png')
